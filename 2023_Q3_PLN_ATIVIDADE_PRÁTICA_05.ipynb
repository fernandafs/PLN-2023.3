# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandafs/PLN-2023.3-Equipe-7/blob/main/2023_Q3_PLN_ATIVIDADE_PR%C3%81TICA_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Processamento de Linguagem Natural [2023.Q3]**
# Prof. Alexandre Donizeti Alves

# %% [markdown]
# ### **ATIVIDADE PRÁTICA 05 [LangChain + Grandes Modelos de Linguagem + API]**

# %% [markdown]
# A **ATIVIDADE PRÁTICA 05** deve ser feita utilizando o **Google Colab** com uma conta sua vinculada ao Gmail. O link do seu notebook, armazenado no Google Drive, além do link de um repositório no GitHub e os principais resultados da atividade, devem ser enviados usando o seguinte formulário:
#
# > https://forms.gle/C1oUi1FKTZ4W9fNdA
#
#
# **IMPORTANTE**: A submissão deve ser feita até o dia **10/12 (domingo)** APENAS POR UM INTEGRANTE DA EQUIPE, até às 23h59. Por favor, lembre-se de dar permissão de ACESSO IRRESTRITO para o professor da disciplina de PLN.

# %% [markdown]
# ### **EQUIPE**
#
# ---

# %% [markdown]
# **POR FAVOR, PREENCHER OS INTEGRANDES DA SUA EQUIPE:**
#
#
# **Integrante 01:**
#
# - Fernanda Felix da Silva RA: 11201921613
#
# **Integrante 02:**
#
# - Ricardo Juniti Kawai RA: 11202021571
#
# **Integrante 03:**
#
# - Samuel Brito da Silva RA: 11201810515

# %% [markdown]
# ### **GRANDE MODELO DE LINGUAGEM (*Large Language Model - LLM*)**
#
# ---

# %% [markdown]
# Cada equipe deve selecionar um Grande Modelo de Linguagem (*Large Language Model - LMM*). Preferencialmente, usar um modelo gratuito. Cada modelo pode ser escolhido por até 2 equipes.
#
# >
#
# Uma lista de LLMs está disponível em:
#
# > https://integrations.langchain.com/llms
# > https://python.langchain.com/docs/integrations/llms/

# %% [markdown]
# **Modelos da Hugging Face:**
#
# * Mistral Base: modelo promissor.
#
# > https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.1
#
# * Mistral Quantizado: mais leve. Pode ser um pouco mais difícil de configurar, mas deve ocupar menos memória.
#
# > https://huggingface.co/TheBloke/Mistral-7B-Instruct-v0.1-GGUF
#
# * Mistral Lite da Amazon: pode ter desempenho melhor.
#
# > https://huggingface.co/amazon/MistralLite
#
# * Llama 2 7B: modelo da Meta melhorado.
#
# > https://huggingface.co/meta-llama/Llama-2-7b-chat-hf
#
# * Llama 2 7b 32k: contexto maior pelo mesmo tamanho.
#
# > https://huggingface.co/togethercomputer/Llama-2-7B-32K-Instruct
#
# * Galactica: para artigos científicos
#
# > https://huggingface.co/facebook/galactica-6.7b
#
# * Alpaca: alternativo ao Llama
#
# > https://huggingface.co/chavinlo/alpaca-native
#
# > https://huggingface.co/spaces/tloen/alpaca-lora

# %% [markdown]
# **Lista de Modelos Interessantes:**
#
# > https://www.kdnuggets.com/2023/04/8-opensource-alternative-chatgpt-bard.html
#
# * Vicuna:
# > https://huggingface.co/lmsys/vicuna-7b-v1.5-16k
#
# * Openchat kit:
# > https://huggingface.co/togethercomputer/GPT-NeoXT-Chat-Base-20B
#
# * Meta OPT:
# > https://huggingface.co/facebook/opt-1.3b
#
# * Google Flan:
# > https://huggingface.co/google/flan-t5-base

# %% [markdown]
# **APIs:**
#
# * GPT4ALL: tenta ser um chatGPT aberto
# > https://python.langchain.com/docs/integrations/llms/gpt4all
#
# * YandexGPT: da empresa russa que criou um modelo de *Machine Learning* clássico muito bom, o CatBoost.
# > https://python.langchain.com/docs/integrations/llms/yandex
#
# * Anthropic: empresa forte concorrente da OpenAi.
# > https://python.langchain.com/docs/integrations/chat/anthropic
#
# * Gorilla: pipeline para geração de código
#  > https://www.kdnuggets.com/2023/06/meet-gorilla-uc-berkeley-microsoft-apiaugmented-llm-outperforms-gpt4-chatgpt-claude.html

# %% [markdown]
# **IMPORTANTE**: todo esse levantamento e comentários foram feitos pelo aluno  **Bruno Sanches Rodrigues**.

# %% [markdown]
# Por favor, informe os dados do LLM selecionada:
#
# >
#
#
# **LLM**: Petals
#
# >
#
# **Link para a documentação oficial**:  https://huggingface.co/petals-team/StableBeluga2
#
# >
#
#
# **Site oficial (GitHub)**: https://github.com/bigscience-workshop/petals

# %% [markdown]
# **IMPORTANTE**: não pode ser o modelo da `OpenAI`.

# %% [markdown]
# ### **API**
# ---

# %% [markdown]
# Por favor, informe os dados da API selecionada:
#
#
# `API:` Youtube
#
# `Site oficial:` https://developers.google.com/youtube/v3?hl=pt-br
#
# `Link para a documentação oficial:`
#  https://developers.google.com/youtube/v3/docs?hl=pt-br

# %% [markdown]
# **IMPORTANTE**: não é necessário usar a mesma **API** da `ATIVIDADE PRÁTICA 03`. Cada **API** pode ser usada por até 2 equipes.

# %% [markdown]
# ### **DESCRIÇÃO**
# ---

# %% [markdown]
# Implementar um `notebook` no `Google Colab` que faça uso do framework **`LangChain`** (obrigatório) e de um **LLM** aplicando, no mínimo, uma técnica de PLN. A técnica pode ser aplicada em qualquer córpus. Também é obrigatório usar uma **API** da `ATIVIDADE PRÁTICA 03`. A **API** pode ser usada tanto para obter os dados quanto para disponibilizar os resultados.
#
# O **LLM** e a **API** selecionados devem ser informados na seguinte planilha:
#
# > https://docs.google.com/spreadsheets/d/1cOL7zVNffqmliuv23zFm1UJjhEXTdp1Zm5EyAJmhiKg/edit?usp=sharing
#
# >
# As seguintes técnicas de PLN podem ser usadas:
#
# *   Correção Gramatical
# *   Classificação de Textos
# *   Análise de Sentimentos
# *   Detecção de Emoções
# *   Extração de Palavras-chave
# *   Tradução de Textos
# *   Sumarização de Textos
# *   Similaridade de Textos
# *   Reconhecimento de Entidades Nomeadas
# *   Sistemas de Perguntas e Respostas
#
# >
#
#
#
#
# **Lista de APIs:**
#
#
# * YouTube
# * LinkedIn
# * Twitter (X)
# * Facebook
# * Instagram
# * Medium
# * Reddit
# * TikTok
# * GitHub
# * Pinterest
# * Telegram
# * Dados financeiros
# * Notícias
# * Mercado de Ações
# * Dados financeiros
# * SMS
# * OpenAlex
# * Whisper (OpenAI)
# * Discord
# * Slack
# * Chuck Norris Jokes
# * Wikipedia
# * Last.fm
# * New York Times
# * Nasdaq Data Link
# * Yahoo! Finance
# * Twilio SendGrid Mail Send
# * Spotify
# * Awesome API
# * Google Books API
# * Mercado Livre API
#
# >
#
# **PLANILHA DA ATIVIDADE PRÁTICA 03:**
#
# > https://docs.google.com/spreadsheets/d/1-Q1szJ3UmoE2_3LtcRQyqid5fPIcnpsR3XAPnoxLj2o/edit?usp=sharing
#
#
# **IMPORTANTE:** É obrigatório usar o e-mail da UFABC.

# %% [markdown]
# ### **CRITÉRIOS DE AVALIAÇÃO**
# ---

# %% [markdown]
# Serão considerados como critérios de avaliação os segunintes pontos:
#
# * Uso do framework **`LangChain`**.
#
# * Escolha e uso de um **LLM**.
#
# * Escolha e uso de uma **API**
#
# * Criatividade no uso do framework **`LangChain`** em conjunto com o **LLM** e a **API**.

# %% [markdown]
# **IMPORTANTE**: todo o código do notebook deve ser executado. Código sem execução não será considerado.

# %% [markdown]
# ### **IMPLEMENTAÇÃO**
# ---

# %% [markdown]
# # Configurações inicias

# %%
# Passo 0: Install LIBS

# !pip install requests
# !pip install langchain
# !pip install python-dotenv
# !pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.6/808.6 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.2/188.2 kB 18.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 37.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.84.0
#     Uninstalling google-api-python-client-2.84.0:
#       Successfully uninstalled google-api-python-client-2.84.0
# ...

# %%
# Passo 1: Imports
import os
import re
from googleapiclient.discovery import build
import pprint

from requests import get
from langchain.chains import LLMChain
from langchain.llms import Petals
from langchain.prompts import PromptTemplate

from dotenv import load_dotenv
# !pip install -U transformers petals # Para conseguir rodar a LLM
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 22.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 14.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 30.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 42.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 28.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.6/85.6 kB 11.6 MB/s eta 0:00:00
# ...

# %%
# Passo 2: Token para acesso a API HuggingFace

from getpass import getpass

HUGGINGFACE_API_KEY = getpass()

os.environ["HUGGINGFACE_API_KEY"] = HUGGINGFACE_API_KEY
# Out:
# ··········

# %%
import requests
# Passo 3: Configuração do youtube data API e extração dos dados

# Insira sua chave de API gerada no Google Cloud Console aqui

video_id = "2fJrM5Okz50" #id do video do tour da UFABC SBC
api_key = "AIzaSyDHJ5h4hcsOO1i9nNlVyIVjT3Sej7R0iR0"
#Busca o vídeo e extrai os comentários
r = requests.get('https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&part=replies&maxResults=5&videoId={}&key={}&alt=json'.format(video_id,api_key)).json()
i=0
comentarios = []
while(i<5): #inserir os comentários em uma lista para a utilização de técnicas de PLN.
  comment = (r['items'][i]['snippet']['topLevelComment']['snippet']['textDisplay'])
  comentarios.append(comment)
  i=i+1
print(comentarios)
# Out:
# ['Eu quero bacharelado em matematica. Quando eu me inscrever, eu escolho BCT? E por consequencia eu disputo com todos os outros que querem outros cursos dentro da BCT?', 'Como é estudar aí? Vale a pena? As federais são tão incríveis como dizem?', 'O aluno sai com duas graduações? Sabe dizer se tem estágio obrigatório?', 'Olá, poderia fazer um video mostrando o hangar e suas aeronaves, talvez até uma entrevista com o pessoal da Eng. Aeroespacial, tenho interesse nessa área. Obrigado e bons vídeos.', 'Vídeo mto bom!! Os alunos podem usar o estacionamento?']

# %%
# Passo 4: Criando instância do Petals e testando conexão

llm = Petals(model_name="petals-team/StableBeluga2")

template = """Question: {question}

Answer: Let's think step by step."""

prompt = PromptTemplate(template=template, input_variables=["question"])

llm_chain = LLMChain(prompt=prompt, llm=llm)

question = "What NFL team won the Super Bowl in the year Justin Beiber was born?"

llm_chain.run(question)
# Out:
# ...
# Dec 12 15:11:42.626 [INFO] Make sure you follow the LLaMA's terms of use: https://bit.ly/llama2-license for LLaMA 2, https://bit.ly/llama-license for LLaMA 1
# Dec 12 15:11:42.627 [INFO] Using DHT prefix: StableBeluga2-hf
# ...
# Dec 12 15:12:06.757 [INFO] Route found: 0:46 via …qKBZ4A => 46:80 via …YjbSKs
# "<s> Question: What NFL team won the Super Bowl in the year Justin Beiber was born?\n\nAnswer: Let's think step by step.\n\nJustin Bieber was born on March 1, 1994.\n\nThe Super Bowl for the 1993 season (Super Bowl XXVIII) was played on January 30, 1994.\n\nThe winning team for that Super Bowl was the Dallas Cowboys.</s>"

# %% [markdown]
# # Aplicação das Técnicas de PLN

# %%
# Técnica 1: Detecção de emoções

import requests

# Insira sua chave de API gerada no Google Cloud Console aqui

video_id = "2fJrM5Okz50" #id do video do tour da UFABC SBC
api_key = "AIzaSyDHJ5h4hcsOO1i9nNlVyIVjT3Sej7R0iR0"
#Busca o vídeo e extrai os comentários
r = requests.get('https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&part=replies&maxResults=5&videoId={}&key={}&alt=json'.format(video_id,api_key)).json()
i=0
comentarios = []
while(i<5): #inserir os comentários em uma lista para a utilização de técnicas de PLN.
  comment = (r['items'][i]['snippet']['topLevelComment']['snippet']['textDisplay'])
  comentarios.append(comment)
  i=i+1

template = """Question: {question}

Answer: Let's think step by step."""

prompt = PromptTemplate(template=template, input_variables=["question"])

llm_chain = LLMChain(prompt=prompt, llm=llm)

question = "Can you detect any emotion in the following comments from a UFABC video: [{}]?".format(comentarios)

print(llm_chain.run(question))
# Out:
# Dec 12 16:36:31.231 [INFO] Route found: 0:46 via …Y9ikh1 => 46:80 via …YjbSKs
# <s> Question: Can you detect any emotion in the following comments from a UFABC video: [['Eu quero bacharelado em matematica. Quando eu me inscrever, eu escolho BCT? E por consequencia eu disputo com todos os outros que querem outros cursos dentro da BCT?', 'Como é estudar aí? Vale a pena? As federais são tão incríveis como dizem?', 'O aluno sai com duas graduações? Sabe dizer se tem estágio obrigatório?', 'Olá, poderia fazer um video mostrando o hangar e suas aeronaves, talvez até uma entrevista com o pessoal da Eng. Aeroespacial, tenho interesse nessa área. Obrigado e bons vídeos.', 'Vídeo mto bom!! Os alunos podem usar o estacionamento?']]?
#
# Answer: Let's think step by step.
#
# First, we can detect some emotions in the comments:
#
# ...

# %%
# Técnica 2: Tradução

import requests

# Insira sua chave de API gerada no Google Cloud Console aqui

video_id = "2fJrM5Okz50" #id do video do tour da UFABC SBC
api_key = "AIzaSyDHJ5h4hcsOO1i9nNlVyIVjT3Sej7R0iR0"
#Busca o vídeo e extrai os comentários
r = requests.get('https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&part=replies&maxResults=5&videoId={}&key={}&alt=json'.format(video_id,api_key)).json()
i=0
comentarios = []
while(i<5): #inserir os comentários em uma lista para a utilização de técnicas de PLN.
  comment = (r['items'][i]['snippet']['topLevelComment']['snippet']['textDisplay'])
  comentarios.append(comment)
  i=i+1

template = """Question: {question}

Answer: Let's think step by step."""

prompt = PromptTemplate(template=template, input_variables=["question"])

llm_chain = LLMChain(prompt=prompt, llm=llm)

question = "Can you translate to English the following comments from a UFABC video: [{}]?".format(comentarios)

print(llm_chain.run(question))
# Out:
# Dec 12 16:22:52.663 [INFO] Route found: 0:46 via …qKBZ4A => 46:80 via …YjbSKs
# <s> Question: Can you translate to English the following comments from a UFABC video: [['Eu quero bacharelado em matematica. Quando eu me inscrever, eu escolho BCT? E por consequencia eu disputo com todos os outros que querem outros cursos dentro da BCT?', 'Como é estudar aí? Vale a pena? As federais são tão incríveis como dizem?', 'O aluno sai com duas graduações? Sabe dizer se tem estágio obrigatório?', 'Olá, poderia fazer um video mostrando o hangar e suas aeronaves, talvez até uma entrevista com o pessoal da Eng. Aeroespacial, tenho interesse nessa área. Obrigado e bons vídeos.', 'Vídeo mto bom!! Os alunos podem usar o estacionamento?']]?
#
# Answer: Let's think step by step.
#
# 1) "Eu quero bacharelado em matematica. Quando eu me inscrever, eu escolho BCT? E por consequencia eu disputo com todos os outros que querem outros cursos dentro da BCT?"
#
# ...

# %%
# Técnica 3: Correção Gramatical

import requests
# Passo 3: Configuração do youtube data API e extração dos dados

# Insira sua chave de API gerada no Google Cloud Console aqui

video_id = "2fJrM5Okz50" #id do video do tour da UFABC SBC
api_key = "AIzaSyDHJ5h4hcsOO1i9nNlVyIVjT3Sej7R0iR0"
#Busca o vídeo e extrai os comentários
r = requests.get('https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&part=replies&maxResults=5&videoId={}&key={}&alt=json'.format(video_id,api_key)).json()
i=0
comentarios = []
while(i<5): #inserir os comentários em uma lista para a utilização de técnicas de PLN.
  comment = (r['items'][i]['snippet']['topLevelComment']['snippet']['textDisplay'])
  comentarios.append(comment)
  i=i+1

template = """Question: {question}

Answer: Let's think step by step."""

prompt = PromptTemplate(template=template, input_variables=["question"])

llm_chain = LLMChain(prompt=prompt, llm=llm)

question = "Can you find grammar mistakes in the following comments of an UFABC video: [{}]?".format(comentarios)

print(llm_chain.run(question))
# Out:
# Dec 12 16:18:50.535 [INFO] Route found: 0:46 via …qKBZ4A => 46:80 via …YjbSKs
# <s> Question: Can you find grammar mistakes in the following comments of an UFABC video: [['Eu quero bacharelado em matematica. Quando eu me inscrever, eu escolho BCT? E por consequencia eu disputo com todos os outros que querem outros cursos dentro da BCT?', 'Como é estudar aí? Vale a pena? As federais são tão incríveis como dizem?', 'O aluno sai com duas graduações? Sabe dizer se tem estágio obrigatório?', 'Olá, poderia fazer um video mostrando o hangar e suas aeronaves, talvez até uma entrevista com o pessoal da Eng. Aeroespacial, tenho interesse nessa área. Obrigado e bons vídeos.', 'Vídeo mto bom!! Os alunos podem usar o estacionamento?']]?
#
# Answer: Let's think step by step.
#
# 1. "Eu quero bacharelado em matematica. Quando eu me inscrever, eu escolho BCT? E por consequencia eu disputo com todos os outros que querem outros cursos dentro da BCT?"
#
# ...

# %%
# Técnica 4: Reconhecimento de entidades nomeadas

import requests

# Insira sua chave de API gerada no Google Cloud Console aqui

video_id = "2fJrM5Okz50" #id do video do tour da UFABC SBC
api_key = "AIzaSyDHJ5h4hcsOO1i9nNlVyIVjT3Sej7R0iR0"
#Busca o vídeo e extrai os comentários
r = requests.get('https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&part=replies&maxResults=5&videoId={}&key={}&alt=json'.format(video_id,api_key)).json()
i=0
comentarios = []
while(i<5): #inserir os comentários em uma lista para a utilização de técnicas de PLN.
  comment = (r['items'][i]['snippet']['topLevelComment']['snippet']['textDisplay'])
  comentarios.append(comment)
  i=i+1

template = """Question: {question}

Answer: Let's think step by step."""

prompt = PromptTemplate(template=template, input_variables=["question"])

llm_chain = LLMChain(prompt=prompt, llm=llm)

question = "Based on the following categories: College, course, pronouns and location, can you perform Named Entity Recognition for comments on a UFABC video: [{}]?".format(comentarios)

print(llm_chain.run(question))
# Out:
# Dec 12 16:14:52.276 [INFO] Route found: 0:46 via …oTbtjr => 46:80 via …YjbSKs
# <s> Question: Based on the following categories: College, course, pronouns and location, can you perform Named Entity Recognition for comments on a UFABC video: [['Eu quero bacharelado em matematica. Quando eu me inscrever, eu escolho BCT? E por consequencia eu disputo com todos os outros que querem outros cursos dentro da BCT?', 'Como é estudar aí? Vale a pena? As federais são tão incríveis como dizem?', 'O aluno sai com duas graduações? Sabe dizer se tem estágio obrigatório?', 'Olá, poderia fazer um video mostrando o hangar e suas aeronaves, talvez até uma entrevista com o pessoal da Eng. Aeroespacial, tenho interesse nessa área. Obrigado e bons vídeos.', 'Vídeo mto bom!! Os alunos podem usar o estacionamento?']]?
#
# Answer: Let's think step by step. First, we need to identify the named entities in the text. In this case, we have:
#
# 1. College: UFABC
# 2. Course: Bacharelado em matematica, BCT
# ...
